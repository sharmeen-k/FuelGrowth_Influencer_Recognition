# %%
import numpy as np
import os

# %%
face = np.load('face_1.npy')
facelist = face.tolist()
facelist.append(21)
np.array(facelist)
# Out:
# array([-6.37445301e-02,  3.57310437e-02,  9.94359236e-03, -3.84219252e-02,
#        -1.46649808e-01,  5.41644394e-02,  3.67546547e-03, -6.81256577e-02,
#         1.77307069e-01, -1.42230272e-01,  1.42753959e-01, -7.39565641e-02,
#        -2.90010363e-01, -2.00451929e-02, -5.11331018e-03,  2.37828389e-01,
#        -1.30625099e-01, -2.21890122e-01, -8.08607787e-02, -6.04532287e-02,
#        -2.20827051e-02,  5.46836555e-02,  3.99585674e-03,  1.26427516e-01,
#        -1.35781989e-01, -4.05237198e-01, -5.80480993e-02, -6.45685792e-02,
#        -1.06204703e-01, -1.04530044e-01, -2.47609466e-02,  1.34046629e-01,
#        -8.85130465e-02, -1.25075448e-02,  1.28150180e-01,  7.64383301e-02,
#        -9.02215913e-02, -8.84244666e-02,  2.57958919e-01,  7.92189240e-02,
#        -2.73479551e-01, -6.17452003e-02,  2.02164844e-01,  2.68872708e-01,
#         2.46040046e-01, -3.60300243e-02,  8.91388580e-03, -4.14891988e-02,
# ...

# %%
face

# %%
face = np.concatenate((face, [0.78]))
#face = np.concatenate((face, [0.87]))
#face = np.concatenate((face, [3.71]))
face
# Out:
# array([-1.67318657e-01,  7.07027316e-02, -2.95500048e-02, -4.11928035e-02,
#        -9.08941850e-02,  6.01694435e-02, -1.93736851e-02, -1.14276774e-01,
#         2.48726249e-01, -1.36785656e-01,  1.61104441e-01, -6.68819472e-02,
#        -1.76751107e-01,  4.97180969e-02, -7.84873888e-02,  1.08960181e-01,
#        -1.21743448e-01, -1.67371958e-01,  1.62467360e-02, -2.78947726e-02,
#         2.38852538e-02, -9.15258937e-03, -1.81442108e-02,  1.32376775e-01,
#        -1.57265201e-01, -3.34751606e-01, -8.64676014e-02, -1.40833601e-01,
#        -1.04319444e-02, -1.24690242e-01, -1.82501338e-02,  6.89713955e-02,
#        -2.12862596e-01, -9.80143249e-03,  5.22385165e-03,  1.28204539e-01,
#         1.42521160e-02, -7.21888766e-02,  2.64253467e-01,  6.08364008e-02,
#        -1.87505871e-01, -1.92851406e-02,  6.56714588e-02,  3.15511346e-01,
#         1.92911908e-01, -1.18518798e-02, -4.72481400e-02, -4.64575775e-02,
# ...

# %%
face = np.concatenate((face, [np.mean(face[128:])]))
face

# %%
np.save(os.getcwd(), face)

# %%
for face in os.listdir():
    if face != "load and check.ipynb":
        file = np.load(face)
        print(face)
# Out:
# face_1.npy
# face_10.npy
# face_11.npy
# face_12.npy
# face_13.npy
# face_14.npy
# face_15.npy
# face_16.npy
# face_17.npy
# face_18.npy
# face_19.npy
# face_1old.npy
# face_2.npy
# face_20.npy
# face_21.npy
# face_22.npy
# face_23.npy
# face_24.npy
# face_25.npy
# face_26.npy
# face_27.npy
# face_28.npy
# face_29.npy
# face_3.npy
# face_30.npy
# face_31.npy
# face_32.npy
# face_33.npy
# face_34.npy
# face_35.npy
# face_36.npy
# face_4.npy
# face_5.npy
# face_6.npy
# face_7.npy
# face_8.npy
# face_9.npy

# %%
os.getcwd()

# %%
face
